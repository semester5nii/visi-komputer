# %% [markdown]
# <a href="https://colab.research.google.com/github/semester5nii/visi-komputer/blob/main/Erosi%20Opening%20Closing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# langsung pakai path file
image_path = "/content/aksara_jawa.png"

# baca gambar
img = cv2.imread(image_path)

# konversi RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# threshold
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)

# kernel
kernel = np.ones((5,5), np.uint8)

# erosi
erosion = cv2.erode(thresh, kernel, iterations=1)

# tampilkan
plt.subplot(1,2,1)
plt.imshow(thresh, cmap='gray')
plt.title("Citra Biner")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(erosion, cmap='gray')
plt.title("Hasil Erosi")
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# langsung pakai path file
image_path = "/content/aksara_jawa.png"

# baca gambar
img = cv2.imread(image_path)

# konversi RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# threshold
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)

# kernel
kernel = np.ones((5,5), np.uint8)

# OPENING (Erosi + Dilasi)
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)

# tampilkan
plt.subplot(1,2,1)
plt.imshow(thresh, cmap='gray')
plt.title("Citra Biner")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(opening, cmap='gray')
plt.title("Hasil Opening")
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# langsung pakai path file
image_path = "/content/aksara_jawa.png"

# baca gambar
img = cv2.imread(image_path)

# konversi RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# threshold
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)

# kernel
kernel = np.ones((5,5), np.uint8)

# CLOSING (Dilasi + Erosi)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# tampilkan
plt.subplot(1,2,1)
plt.imshow(thresh, cmap='gray')
plt.title("Citra Biner")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(closing, cmap='gray')
plt.title("Hasil Closing")
plt.axis('off')

plt.show()
